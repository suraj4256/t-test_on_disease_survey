# %%
import pandas as pd

# %%
df= pd.read_excel('Copy of kalyani-data(1)........xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DATE                21 non-null     datetime64[ns]
#  1   S.NO.               21 non-null     float64
#  2   NAME                21 non-null     object
#  3   AGE                 21 non-null     object
#  4   SEX                 21 non-null     object
#  5   ADDRESS             21 non-null     object
#  6   CELL NUMBER         21 non-null     object
#  7   BLOOD GROUP         21 non-null     object
#  8   FOOD PREFERENCE     21 non-null     object
#  9   DISEASE ASSOCIATED  21 non-null     object
#  10  DATE OF OCCURANCE   22 non-null     object
#  11  DURATION            22 non-null     object
#  12  PROFESSION          21 non-null     object
#  13  WORKING HOURS       21 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(12)
# memory usage: 4.8+ KB

# %%
df = df[df['AGE'].notna()]

# %%
df
# Out:
#          DATE  S.NO.                        NAME      AGE SEX  \
# 1  2025-06-27  213.0                MITA GANGULY  67 YRS.  F
# 3  2025-06-27  214.0               DEEPA GANGULY  32 YRS.  F
# 5  2025-06-27  215.0              RANJIT GANGULY  40 YRS.   M
# 7  2025-06-27  216.0             MANJITA GANGULY  38 YRS.  F
# 9  2025-06-27  217.0             NARAYAN GANGULY   76 YRS   M
# 12 2025-06-27  218.0                SABITRA SAHA  33 YRS.  F
# 14 2025-06-27  219.0                SUVAYAN SAHA  35 YRS.   M
# 16 2025-06-27  220.0                  YUVAN SAHA  06 YRS.   M
# 18 2025-07-15  331.0                   RUMKI SEN  29 YRS.  F
# 20 2025-07-15  332.0                  LABONI SEN  34 YRS.  F
# 22 2025-07-15  333.0                NIHARIKA SEN  46 YRS.  F
# 24 2025-07-15  334.0                  ADIRAJ SEN  12 YRS.  M
# 26 2025-07-15  335.0                    AMAM SEN  54 YRS.  M
# 28 2025-07-15  336.0                RAJAT BISWAS  67 YRS.  M
# ...

# %%
df.drop(['DATE', 'CELL NUMBER','FOOD PREFERENCE','DATE OF OCCURANCE','DURATION','PROFESSION','WORKING HOURS'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    S.NO.             NAME      AGE SEX                  ADDRESS BLOOD GROUP  \
# 1  213.0     MITA GANGULY  67 YRS.  F   A1-47, A BLOCK, KALYANI          B+
# 3  214.0    DEEPA GANGULY  32 YRS.  F   A1-47, A BLOCK, KALYANI          A+
# 5  215.0   RANJIT GANGULY  40 YRS.   M  A1-47, A BLOCK, KALYANI          A+
# 7  216.0  MANJITA GANGULY  38 YRS.  F   A1-47, A BLOCK, KALYANI          B+
# 9  217.0  NARAYAN GANGULY   76 YRS   M  A1-47, A BLOCK, KALYANI          B+
#
#                                   DISEASE ASSOCIATED
# 1                       DIABETICS, FIBROSIS OF LIVER
# 3                                       OVARIAN CYST
# 5                                        CHOLOESTROL
# 7                                                NIL
# 9  CATARACT OPERATION, CHOLOESTROL, DIABETICS, LI...

# %%
df['S.NO.'] = range(1,len(df)+1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 1 to 42
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.NO.               21 non-null     int64
#  1   NAME                21 non-null     object
#  2   AGE                 21 non-null     object
#  3   SEX                 21 non-null     object
#  4   ADDRESS             21 non-null     object
#  5   BLOOD GROUP         21 non-null     object
#  6   DISEASE ASSOCIATED  21 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.3+ KB

# %%
len(df)
# Out:
# 21

# %%
df['ADDRESS']='KALYANI'

# %%
df.head()
# Out:
#    S.NO.             NAME      AGE SEX  ADDRESS BLOOD GROUP  \
# 1      1     MITA GANGULY  67 YRS.  F   KALYANI          B+
# 3      2    DEEPA GANGULY  32 YRS.  F   KALYANI          A+
# 5      3   RANJIT GANGULY  40 YRS.   M  KALYANI          A+
# 7      4  MANJITA GANGULY  38 YRS.  F   KALYANI          B+
# 9      5  NARAYAN GANGULY   76 YRS   M  KALYANI          B+
#
#                                   DISEASE ASSOCIATED
# 1                       DIABETICS, FIBROSIS OF LIVER
# 3                                       OVARIAN CYST
# 5                                        CHOLOESTROL
# 7                                                NIL
# 9  CATARACT OPERATION, CHOLOESTROL, DIABETICS, LI...

# %%
df.to_excel('Cleaned_Kalyani_Final_01.xlsx', index=False)
