# %%
import pandas as pd

df_chakdaha = pd.read_excel('Cleaned_Chakdaha_Final.xlsx')
df_palpara = pd.read_excel('Cleaned_Palpara_Final.xlsx')
df_simurali = pd.read_excel('Cleaned_Simurali_Final.xlsx')
df_kalyani = pd.read_excel('Cleaned_Kalyani_Final_01.xlsx')
df_naihati = pd.read_excel('Cleaned_Naihati.xlsx')

# %%
df_chakdaha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.NO.               151 non-null    int64
#  1   NAME                151 non-null    object
#  2   AGE                 151 non-null    object
#  3   SEX                 151 non-null    object
#  4   ADDRESS             151 non-null    object
#  5   BLOOD GROUP         151 non-null    object
#  6   DISEASE ASSOCIATED  151 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 8.4+ KB

# %%
df_palpara.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.NO.               150 non-null    int64
#  1   NAME                150 non-null    object
#  2   AGE                 150 non-null    object
#  3   SEX                 150 non-null    object
#  4   ADDRESS             150 non-null    object
#  5   BLOOD GROUP         150 non-null    object
#  6   DISEASE ASSOCIATED  150 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 8.3+ KB

# %%
df_kalyani.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.NO.               21 non-null     int64
#  1   NAME                21 non-null     object
#  2   AGE                 21 non-null     object
#  3   SEX                 21 non-null     object
#  4   ADDRESS             21 non-null     object
#  5   BLOOD GROUP         21 non-null     object
#  6   DISEASE ASSOCIATED  21 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.3+ KB

# %%
df_naihati.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.NO.               18 non-null     int64
#  1   NAME                18 non-null     object
#  2   AGE                 18 non-null     object
#  3   SEX                 18 non-null     object
#  4   ADDRESS             18 non-null     object
#  5   BLOOD GROUP         18 non-null     object
#  6   DISEASE ASSOCIATED  18 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.1+ KB

# %%
df_naihati.head(11)
# Out:
#     S.NO.            NAME      AGE SEX  ADDRESS BLOOD GROUP  \
# 0       1    SANTI SIMLAI  69 YRS.  F   NAIHATI          B+
# 1       2   NABITA SIMALI  30 YRS.  F   NAIHATI          A+
# 2       3  BABULAL SIMALI  38 YRS.   M  NAIHATI          B+
# 3       4  SHAROLO SIMLAI  04 YRS.   M  NAIHATI          B+
# 4       5    ARITRA GHOSH  22 YRS.   M  NAIHATI          A+
# 5       6      DEBU GHOSH  45 YRS.   M  NAIHATI          A+
# 6       7     ARATI GHOSH  43 YRS.  F   NAIHATI          B+
# 7       8      DEBASIS DE  54 YRS.   M  NAIHATI          O-
# 8       9       NILIMA DE  50 YRS.  F   NAIHATI          A+
# 9      10         RIVU DE  19 YRS.   M  NAIHATI          A+
# 10     11        LAXMI DE  89 YRS.  F   NAIHATI          B+
#
#                                    DISEASE ASSOCIATED
# 0                                ARITHRITIS,THYROID,
# 1                                                PCOS
# 2                                                 NIL
# ...

# %%
df_naihati.tail()
# Out:
#     S.NO.          NAME      AGE SEX  ADDRESS BLOOD GROUP  \
# 13     14    ANKIT PAUL  12 YRS.   M  NAIHATI         AB+
# 14     15  PRIYA HALDER  34 YRS.   F  NAIHATI          A+
# 15     16    SUMAN SAHA  40 YRS.   M  NAIHATI          B+
# 16     17    RIYA GHOSH  26 YRS.   F  NAIHATI          O+
# 17     18  BISWAJIT DAS  18 YRS.   M  NAIHATI          A+
#
#         DISEASE ASSOCIATED
# 13          COUGH AND COLD
# 14                 ALLERGY
# 15                     NIL
# 16  PCOS, THYROID DISORDER
# 17                     NIL

# %%
df_simurali.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.NO.               41 non-null     int64
#  1   NAME                41 non-null     object
#  2   AGE                 41 non-null     object
#  3   SEX                 41 non-null     object
#  4   ADDRESS             41 non-null     object
#  5   BLOOD GROUP         41 non-null     object
#  6   DISEASE ASSOCIATED  41 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.4+ KB

# %%
length= len(df_simurali)+len(df_chakdaha)+len(df_palpara)+len(df_kalyani)+len(df_naihati)
print(length)
# Out:
# 381

# %%
# Out:
# 23

# %%
df_combined = pd.concat([
    df_chakdaha,
    df_palpara,
    df_simurali,
    df_kalyani,
    df_naihati
])

# %%
df_combined.drop(['DATE', 'CELL NUMBER','FOOD PREFERENCE','DATE OF OCCURANCE','DURATION','PROFESSION','WORKING HOURS'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_combined.drop(['DATE', 'CELL NUMBER','FOOD PREFERENCE','DATE OF OCCURANCE','DURATION','PROFESSION','WORKING HOURS'], axis=1, inplace=True)
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
# ...

# %%
df_combined['S.NO.'] = range(1,len(df_combined)+1)

# %%
df_combined.tail()
# Out:
#     S.NO.          NAME      AGE SEX  ADDRESS BLOOD GROUP  \
# 13    377    ANKIT PAUL  12 YRS.   M  NAIHATI         AB+
# 14    378  PRIYA HALDER  34 YRS.   F  NAIHATI          A+
# 15    379    SUMAN SAHA  40 YRS.   M  NAIHATI          B+
# 16    380    RIYA GHOSH  26 YRS.   F  NAIHATI          O+
# 17    381  BISWAJIT DAS  18 YRS.   M  NAIHATI          A+
#
#         DISEASE ASSOCIATED
# 13          COUGH AND COLD
# 14                 ALLERGY
# 15                     NIL
# 16  PCOS, THYROID DISORDER
# 17                     NIL

# %%
df_combined.to_excel("Address_Sorted_File_2.xlsx", index=False)

# %%
df_combined = df_combined[df_combined['Age'].notna()]

# %%
df_combined.head(10)
# Out:
#          Date  S. No.             Name      Age Gender   Address  \
# 0  2025-06-11       1    ALIVIA PIPLAI  30 YRS.      F  CHAKDAHA
# 3  2025-06-11       4    BULBUL PIPLAI   63 YRS      F  CHAKDAHA
# 5  2025-06-11       6  MONOTOSH PIPLAI  74 YRS.      M  CHAKDAHA
# 7  2025-06-11       8      ESHA PIPLAI  36 YRS.      F  CHAKDAHA
# 9  2025-06-11      10     ALO RANI DAS  89 YRS.      F  CHAKDAHA
# 11 2025-06-11      12     PROSANTO DAS  60 YRS.      M  CHAKDAHA
# 13 2025-06-11      14         RUMA DAS  48 YRS.      F  CHAKDAHA
# 15 2025-06-11      16       SONALI DAS  25 YRS.      F  CHAKDAHA
# 17 2025-06-11      18       SWAPAN RAY  62 YRS.      M  CHAKDAHA
# 19 2025-06-11      20          ALO ROY  51 YRS.      F  CHAKDAHA
#
#      Phone Number Blood Group Food Preference  \
# 0      8927200122          O+         NON VEG
# 3      8927200122          O-         NON VEG
# 5      8927200122          O+         NON VEG
# 7      7872911777          O-         NON VEG
# ...

# %%
df_combined['S. No.'] = range(1,len(df_combined)+1)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21888\364759878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_combined['S. No.'] = range(1,len(df_combined)+1)

# %%
df_combined.head(10)
# Out:
#          Date  S. No.             Name      Age Gender   Address  \
# 0  2025-06-11       1    ALIVIA PIPLAI  30 YRS.      F  CHAKDAHA
# 3  2025-06-11       2    BULBUL PIPLAI   63 YRS      F  CHAKDAHA
# 5  2025-06-11       3  MONOTOSH PIPLAI  74 YRS.      M  CHAKDAHA
# 7  2025-06-11       4      ESHA PIPLAI  36 YRS.      F  CHAKDAHA
# 9  2025-06-11       5     ALO RANI DAS  89 YRS.      F  CHAKDAHA
# 11 2025-06-11       6     PROSANTO DAS  60 YRS.      M  CHAKDAHA
# 13 2025-06-11       7         RUMA DAS  48 YRS.      F  CHAKDAHA
# 15 2025-06-11       8       SONALI DAS  25 YRS.      F  CHAKDAHA
# 17 2025-06-11       9       SWAPAN RAY  62 YRS.      M  CHAKDAHA
# 19 2025-06-11      10          ALO ROY  51 YRS.      F  CHAKDAHA
#
#      Phone Number Blood Group Food Preference  \
# 0      8927200122          O+         NON VEG
# 3      8927200122          O-         NON VEG
# 5      8927200122          O+         NON VEG
# 7      7872911777          O-         NON VEG
# ...

# %%
df_combined.to_excel('Address_Sorted_File.xlsx', index=False)

# %%
disease_mapping = {
    "DIABETIC": "DIABETES",
    "DIABTIC": "DIABETES",
    "DIABETIC MELLITUS": "DIABETES",
    "HYPERTENSIVE": "HYPERTENSION",
    "HYPERTENSION": "HYPERTENSION",
    "CHOLESTEROL": "HIGH CHOLESTEROL",
    "CHLOESTROL": "HIGH CHOLESTEROL",
    "ALLERGIC": "ALLERGY",
    "PEPTIC ULCER": "ULCER",
    "GASTRIC PROBLEM": "ULCER",
    "THYROID": "THYROID DISORDER",
    "HYPOTHYROIDISM": "THYROID DISORDER",
    "HIGH BP": "HYPERTENSION",
    "BP": "HYPERTENSION"
}
